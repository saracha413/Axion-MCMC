# %%
import matplotlib
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

from os import listdir
from os.path import isfile, join

# %%
#find the files in directory
#from https://stackoverflow.com/questions/3207219/how-do-i-list-all-files-of-a-directory
path = '/Users/saravannah/Axion-MCMC/axion_MCMC/Oct-27-runs/chains/'
name = 'Oct'
files = [f for f in listdir(path) if isfile(join(path, f))]

for fileName in files:
    if name in fileName:
        log10_axion_ac, log10_fraction_axion_ac, omega_cdm, H0, Djs = np.loadtxt(path+fileName, unpack=True)
        print(fileName,' has len ', len(log10_axion_ac))
        steps = np.arange(0, len(log10_axion_ac))
        plt.plot(steps, log10_fraction_axion_ac)
# Out:
# Oct-27#8.txt  has len  500
# Oct-27#9.txt  has len  500
# Oct-27#1.txt  has len  500
# Oct-27#0.txt  has len  500
# Oct-27#2.txt  has len  500
# Oct-27#3.txt  has len  500
# Oct-27#7.txt  has len  500
# Oct-27#6.txt  has len  500
# Oct-27#4.txt  has len  500
# Oct-27#5.txt  has len  500
